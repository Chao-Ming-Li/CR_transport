# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
matplotlib.rcParams["mathtext.fontset"] = "cm"
plt.rcParams["font.family"] = "serif"
import matplotlib.colors as colors
import gc

# %%
NX = 20001
NT = 7
D = 1000.0
L = 10000.0
q = 1.0
v = 1.0
t = np.logspace(-4, 2, NT)
x = np.linspace(-L,L,NX)

ndis_Pe001_gf_uw = np.fromfile("ndis_Pe001_gf_uw.bin", dtype=np.float64)
ndis_Pe001_gf_uw = ndis_Pe001_gf_uw.reshape(NT,NX)
ndis_Pe001_gf_uw_feb = np.fromfile("ndis_Pe001_gf_uw_feb.bin", dtype=np.float64)
ndis_Pe001_gf_uw_feb = ndis_Pe001_gf_uw_feb.reshape(NT,10001)

ndis_Pe001_ana = np.exp(-(x[None,:] - v*t[:,None])**2 / 4 / D / t[:,None]) / np.sqrt(4*np.pi*D*t[:,None])

for i in range(NT):
    plt.plot(x[10000:], ndis_Pe001_gf_uw[i,10000:], label="t = 10^" + str(i-4) + " cd")
# for i in range(NT):
#     plt.scatter(x[10000:], ndis_Pe001_ana[i,10000:], label="ana")
for i in range(NT):
    plt.scatter(x[10000:], ndis_Pe001_gf_uw_feb[i], label="feb")

plt.xscale('log')  
plt.yscale("log")
plt.legend(ncol=2)
plt.ylim(1e-5,1e0)
plt.title("Pe = 0.001")
# Out:
# Text(0.5, 1.0, 'Pe = 0.001')

# %%
ls *feb.bin
# Out:
# ndis_Pe001_gf_uw_feb.bin
